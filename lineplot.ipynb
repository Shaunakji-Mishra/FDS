# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaunakji-Mishra/FDS/blob/main/lineplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
gdata=pd.read_csv("/content/drive/MyDrive/FDS/FDS/smallgradesh.csv")
import seaborn as sns
import matplotlib.pylab as plt


print(gdata.head())
sns.lineplot(data=gdata, x="Name", y="Grade")
# Out:
#       Name  Grade
# 0   Marcia   82.4
# 1   Kadeem   78.2
# 2     Nash   79.3
# 3  Noelani   83.2
# 4  Noelani   87.4
